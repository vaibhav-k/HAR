# %%
# CNN model with filters
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical

# %%
# load a single file as a numpy array
def load_file(filepath):
    dataframe = read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix = ""):
    filepath = prefix + group + "/Inertial Signals/"
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ["total_acc_x_" + group + ".txt", "total_acc_y_" + group + ".txt",
                  "total_acc_z_" + group + ".txt"]
    # body acceleration
    filenames += ['body_acc_x_' + group + ".txt", "body_acc_y_" + group + ".txt",
                  "body_acc_z_" + group + ".txt"]
    # body gyroscope
    filenames += ["body_gyro_x_" + group + ".txt", "body_gyro_y_" + group + ".txt",
                  "body_gyro_z_" + group + ".txt"]
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + "/y_" + group + ".txt")
    return X, y

# load the dataset, returns train and test X and y elements
def load_dataset(prefix = ""):
    print("Before one-hot encoding")
    # load all train
    trainX, trainy = load_dataset_group("train", prefix + "HARDataset/")
    print("X-train shape", trainX.shape)
    print("Y-train shape", trainy.shape)
    # load all test
    testX, testy = load_dataset_group("test", prefix + "HARDataset/")
    print("X-test shape", testX.shape)
    print("Y-test shape", testy.shape)
    # zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    # one hot encode y
    print("\nAfter one-hot encoding")
    trainy = to_categorical(trainy)
    testy = to_categorical(testy)
    print("X-train shape", trainX.shape)
    print("Y-train shape", trainy.shape)
    print("X-test shape", testX.shape)
    print("Y-test shape", testy.shape)
    return trainX, trainy, testX, testy

# fit and evaluate a model
def evaluate_model(trainX, trainy, testX, testy, n_filters):
    verbose, epochs, batch_size = 0, 10, 32
    n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
    model = Sequential()
    model.add(Conv1D(filters = n_filters, kernel_size = 3, activation = "relu",
                     input_shape = (n_timesteps, n_features)))
    model.add(Conv1D(filters = n_filters, kernel_size = 3, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size = 2))
    model.add(Flatten())
    model.add(Dense(100, activation = "relu"))
    model.add(Dense(n_outputs, activation = "softmax"))
    model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    # fit network
    model.fit(trainX, trainy, epochs = epochs, batch_size = batch_size, verbose = verbose)
    # evaluate model
    _, accuracy = model.evaluate(testX, testy, batch_size = batch_size, verbose = 0)
    return accuracy
 
# summarize scores
def summarize_results(scores, params):
    print(scores, params)
    # summarize mean and standard deviation
    for i in range(len(scores)):
        m, s = mean(scores[i]), std(scores[i])
        print("\nNumber of filters = %d: %.3f%% (+/-%.3f)" % (params[i], m, s))
    # boxplot of scores
    pyplot.boxplot(scores, labels=params)
    pyplot.savefig("exp_cnn_filters.png")

# run an experiment
def run_experiment(params, repeats=10):
    # load data
    trainX, trainy, testX, testy = load_dataset()
    # test each parameter
    all_scores = list()
    for p in params:
        # repeat experiment
        scores = list()
        print()
        for r in range(repeats):
            score = evaluate_model(trainX, trainy, testX, testy, p)
            score = score * 100.0
            print("Number of filters = %d, Iteration %d: %.3f" % (p, r+1, score))
            scores.append(score)
        all_scores.append(scores)
    # summarize results
    summarize_results(all_scores, params)

# %%
# run the experiment
n_params = [8, 16, 32, 64, 128, 256]
run_experiment(n_params)
# Out:
# Before one-hot encoding
# X-train shape (7352, 128, 9)
# Y-train shape (7352, 1)
# X-test shape (2947, 128, 9)
# Y-test shape (2947, 1)
#
# After one-hot encoding
# X-train shape (7352, 128, 9)
# Y-train shape (7352, 6)
# X-test shape (2947, 128, 9)
# Y-test shape (2947, 6)
#
# Number of filters = 8, Iteration 1: 88.056
# Number of filters = 8, Iteration 2: 90.567
# Number of filters = 8, Iteration 3: 87.275
# Number of filters = 8, Iteration 4: 89.922
# Number of filters = 8, Iteration 5: 89.108
# Number of filters = 8, Iteration 6: 88.972
# Number of filters = 8, Iteration 7: 88.090
# Number of filters = 8, Iteration 8: 88.327
# Number of filters = 8, Iteration 9: 86.155
# Number of filters = 8, Iteration 10: 87.004
#
# Number of filters = 16, Iteration 1: 90.465
# Number of filters = 16, Iteration 2: 88.666
# Number of filters = 16, Iteration 3: 88.463
# Number of filters = 16, Iteration 4: 89.074
# Number of filters = 16, Iteration 5: 89.888
# Number of filters = 16, Iteration 6: 89.990
# Number of filters = 16, Iteration 7: 91.110
# Number of filters = 16, Iteration 8: 89.617
# Number of filters = 16, Iteration 9: 89.040
# Number of filters = 16, Iteration 10: 91.110
#
# Number of filters = 32, Iteration 1: 88.599
# Number of filters = 32, Iteration 2: 90.974
# Number of filters = 32, Iteration 3: 90.431
# Number of filters = 32, Iteration 4: 91.415
# Number of filters = 32, Iteration 5: 90.329
# Number of filters = 32, Iteration 6: 89.650
# Number of filters = 32, Iteration 7: 90.601
# Number of filters = 32, Iteration 8: 88.531
# Number of filters = 32, Iteration 9: 89.854
# Number of filters = 32, Iteration 10: 87.954
#
# Number of filters = 64, Iteration 1: 90.295
# Number of filters = 64, Iteration 2: 91.381
# Number of filters = 64, Iteration 3: 90.838
# Number of filters = 64, Iteration 4: 90.092
# Number of filters = 64, Iteration 5: 89.752
# Number of filters = 64, Iteration 6: 90.838
# Number of filters = 64, Iteration 7: 86.698
# Number of filters = 64, Iteration 8: 90.940
# Number of filters = 64, Iteration 9: 90.193
# Number of filters = 64, Iteration 10: 91.619
#
# Number of filters = 128, Iteration 1: 89.786
# Number of filters = 128, Iteration 2: 89.956
# Number of filters = 128, Iteration 3: 89.922
# Number of filters = 128, Iteration 4: 89.141
# Number of filters = 128, Iteration 5: 91.110
# Number of filters = 128, Iteration 6: 92.094
# Number of filters = 128, Iteration 7: 90.974
# Number of filters = 128, Iteration 8: 89.481
# Number of filters = 128, Iteration 9: 91.924
# Number of filters = 128, Iteration 10: 92.399
#
# Number of filters = 256, Iteration 1: 91.211
# Number of filters = 256, Iteration 2: 91.144
# Number of filters = 256, Iteration 3: 91.788
# Number of filters = 256, Iteration 4: 92.229
# Number of filters = 256, Iteration 5: 92.094
# Number of filters = 256, Iteration 6: 90.668
# Number of filters = 256, Iteration 7: 91.551
# Number of filters = 256, Iteration 8: 91.483
# Number of filters = 256, Iteration 9: 89.956
# Number of filters = 256, Iteration 10: 90.872
# [[88.05565237998962, 90.56667685508728, 87.27519512176514, 89.92195725440979, 89.10756707191467, 88.97183537483215, 88.08958530426025, 88.32710981369019, 86.15541458129883, 87.0037317276001], [90.46487808227539, 88.66643905639648, 88.4628415107727, 89.07363414764404, 89.88802433013916, 89.98982310295105, 91.10960364341736, 89.61656093597412, 89.03970122337341, 91.10960364341736], [88.59857320785522, 90.97387194633484, 90.43094515800476, 91.41499996185303, 90.32914638519287, 89.65049386024475, 90.60060977935791, 88.53070735931396, 89.85409140586853, 87.95385360717773], [90.29521346092224, 91.3810670375824, 90.83814024925232, 90.09161591529846, 89.75229263305664, 90.83814024925232, 86.69833540916443, 90.93993902206421, 90.19341468811035, 91.6185975074768], [89.78622555732727, 89.95589017868042, 89.92195725440979, 89.1414999961853, 91.10960364341736, 92.09365248680115, 90.97387194633484, 89.4808292388916, 91.923987865448, 92.39904880523682], [91.21140241622925, 91.14353656768799, 91.78826212882996, 92.22938418388367, 92.09365248680115, 90.66847562789917, 91.55073165893555, 91.48286581039429, 89.95589017868042, 90.87207317352295]] [8, 16, 32, 64, 128, 256]
#
# mber of filters = 8: 88.347% (+/-1.276)
#
# mber of filters = 16: 89.742% (+/-0.900)
#
# mber of filters = 32: 89.834% (+/-1.085)
#
# mber of filters = 64: 90.265% (+/-1.312)
#
# mber of filters = 128: 90.679% (+/-1.117)
#
# mber of filters = 256: 91.300% (+/-0.652)
