# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import coremltools
from scipy import stats
from IPython.display import display, HTML
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
# Out:
# WARNING:root:scikit-learn version 0.24.0 is not supported. Minimum required version: 0.17. Maximum required version: 0.19.2. Disabling scikit-learn conversion API.
# WARNING:root:TensorFlow version 2.4.0 detected. Last version known to be fully compatible is 2.3.1 .
# WARNING:root:Keras version 2.4.3 detected. Last version known to be fully compatible of Keras is 2.2.4 .

# %%
pd.options.display.float_format = "{:.1f}".format # Set some standard parameters upfront
sns.set() # Default seaborn look and feel
plt.style.use("ggplot")
print("Keras version ", keras.__version__)
LABELS = ["Downstairs", "Jogging", "Sitting", "Standing", "Upstairs", "Walking"]
# The number of steps within one time segment
TIME_PERIODS = 80
# The steps to take from one segment to the next; if this value is equal to TIME_PERIODS, then there is
# no overlap between the segments
STEP_DISTANCE = 40
# Out:
# keras version  2.4.3

# %%
def read_data(file_path):
    column_names = ["user-id", "activity", "timestamp", "x-axis", "y-axis", "z-axis"]
    df = pd.read_csv(file_path, header = None, names = column_names)
    # Last column has a ";" character which must be removed ...
    df["z-axis"].replace(regex = True, inplace = True, to_replace = r';', value = r'')
    # ... and then this column must be transformed to float explicitly
    df["z-axis"] = df["z-axis"].apply(convert_to_float)
    # This is very important otherwise the model will not fit and loss will show up as NAN
    df.dropna(axis=0, how='any', inplace=True)
    return df

def convert_to_float(x):
    try:
        return np.float(x)
    except:
        return np.nan
    
def show_basic_dataframe_info(dataframe):
    # Shape and how many rows and columns
    print("Number of columns in the dataframe: %i" % (dataframe.shape[1]))
    print("Number of rows in the dataframe: %i\n" % (dataframe.shape[0]))

# Load data set containing all the data from csv
df = read_data("./WISDM_ar_latest/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt")

# %%
# Describe the data
show_basic_dataframe_info(df)
df.head(20)
# Out:
# Number of columns in the dataframe: 6
# Number of rows in the dataframe: 1098203
#     user-id activity       timestamp  x-axis  y-axis  z-axis
# 0        33  Jogging  49105962326000    -0.7    12.7     0.5
# 1        33  Jogging  49106062271000     5.0    11.3     1.0
# 2        33  Jogging  49106112167000     4.9    10.9    -0.1
# 3        33  Jogging  49106222305000    -0.6    18.5     3.0
# 4        33  Jogging  49106332290000    -1.2    12.1     7.2
# 5        33  Jogging  49106442306000     1.4    -2.5    -6.5
# 6        33  Jogging  49106542312000    -0.6    10.6     5.7
# 7        33  Jogging  49106652389000    -0.5    13.9     7.1
# 8        33  Jogging  49106762313000    -8.4    11.4     5.1
# 9        33  Jogging  49106872299000     1.0     1.4     1.6
# 10       33  Jogging  49106982315000    -8.2    19.6     2.7
# 11       33  Jogging  49107092330000     1.4     5.8     3.0
# 12       33  Jogging  49107202316000    -1.9    -3.0    -0.3
# 13       33  Jogging  49107312332000    -6.1     6.9    -8.2
# 14       33  Jogging  49107422348000     5.8    18.0     8.5
# 15       33  Jogging  49107522293000     6.3     3.0     2.9
# 16       33  Jogging  49107632339000    -1.6     8.3    -1.5
# 17       33  Jogging  49107742355000     3.5    13.6     9.4
# 18       33  Jogging  49107852340000    -2.0    -5.7   -10.2
# 19       33  Jogging  49107962326000     2.8    10.3    -9.7

# %%
# Show how many training examples exist for each of the six activities
df["activity"].value_counts().plot(kind = "bar", title = "Training Examples by Activity Type")
plt.show()
# Better understand how the recordings are spread across the different users who participated in the study
df["user-id"].value_counts().plot(kind = "bar", title = "Training Examples by User")
plt.show()

# %%
def plot_activity(activity, data):
    fig, (ax0, ax1, ax2) = plt.subplots(nrows = 3, figsize = (15, 10), sharex = True)
    plot_axis(ax0, data["timestamp"], data["x-axis"], "X-Axis")
    plot_axis(ax1, data["timestamp"], data["y-axis"], "Y-Axis")
    plot_axis(ax2, data["timestamp"], data["z-axis"], "Z-Axis")
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(activity)
    plt.subplots_adjust(top=0.90)
    plt.show()

def plot_axis(ax, x, y, title):
    ax.plot(x, y, 'r')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for activity in np.unique(df["activity"]):
    subset = df[df["activity"] == activity][:180]
    plot_activity(activity, subset)

# %%
# Define column name of the label vector
LABEL = "ActivityEncoded"
# Transform the labels from String to Integer via LabelEncoder
le = preprocessing.LabelEncoder()
# Add a new column to the existing DataFrame with the encoded values
df[LABEL] = le.fit_transform(df["activity"].values.ravel())

# %%
# Differentiate between test set and training set
df_test = df[df["user-id"] > 28]
df_train = df[df["user-id"] <= 28]

# %%
# Normalize features for training data set (values between 0 and 1)
# Surpress warning for next 3 operation
pd.options.mode.chained_assignment = None  # default='warn'
df_train["x-axis"] = df_train["x-axis"] / df_train["x-axis"].max()
df_train["y-axis"] = df_train["y-axis"] / df_train["y-axis"].max()
df_train["z-axis"] = df_train["z-axis"] / df_train["z-axis"].max()
# Round numbers
df_train = df_train.round({"x-axis": 4, "y-axis": 4, "z-axis": 4})

# %%
def create_segments_and_labels(df, time_steps, step, label_name):
    # x, y, z acceleration as features
    N_FEATURES = 3
    # Number of steps to advance in each iteration (for me, it should always
    # be equal to the time_steps in order to have no overlap between segments)
    # step = time_steps
    segments = []
    labels = []
    for i in range(0, len(df) - time_steps, step):
        xs = df["x-axis"].values[i: i + time_steps]
        ys = df["y-axis"].values[i: i + time_steps]
        zs = df["z-axis"].values[i: i + time_steps]
        # Retrieve the most often used label in this segment
        label = stats.mode(df[label_name][i: i + time_steps])[0][0]
        segments.append([xs, ys, zs])
        labels.append(label)
    # Bring the segments into a better shape
    reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, time_steps, N_FEATURES)
    labels = np.asarray(labels)
    return reshaped_segments, labels

x_train, y_train = create_segments_and_labels(df_train, TIME_PERIODS, STEP_DISTANCE, LABEL)

# %%
print("x_train shape: ", x_train.shape)
print(x_train.shape[0], 'training samples')
print("y_train shape: ", y_train.shape)
# Out:
# x_train shape:  (20868, 80, 3)
# 20868 training samples
# y_train shape:  (20868,)

# %%
# Set input & output dimensions
num_time_periods, num_sensors = x_train.shape[1], x_train.shape[2]
num_classes = le.classes_.size
print(list(le.classes_))
# Out:
# ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

# %%
input_shape = (num_time_periods*num_sensors)
x_train = x_train.reshape(x_train.shape[0], input_shape)
print("x_train shape: ", x_train.shape)
print("input_shape: ", input_shape)
# Out:
# x_train shape: (20868, 240)
# input_shape: 240

# %%
x_train = x_train.astype("float32")
y_train = y_train.astype("float32")

# %%
y_train_hot = np_utils.to_categorical(y_train, num_classes)
print("New y_train shape: ", y_train_hot.shape)
# Out:
# New y_train shape:  (20868, 6)

# %%
model_m = Sequential()
# Remark: since coreml cannot accept vector shapes of complex shape like
# [80,3] this workaround is used in order to reshape the vector internally
# prior feeding it into the network
model_m.add(Reshape((TIME_PERIODS, 3), input_shape = (input_shape,)))
model_m.add(Dense(100, activation = "relu"))
model_m.add(Dense(100, activation = "relu"))
model_m.add(Dense(100, activation = "relu"))
model_m.add(Flatten())
model_m.add(Dense(num_classes, activation = "softmax"))
print(model_m.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 80, 3)             0
# _________________________________________________________________
# dense (Dense)                (None, 80, 100)           400
# _________________________________________________________________
# dense_1 (Dense)              (None, 80, 100)           10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 80, 100)           10100
# _________________________________________________________________
# flatten (Flatten)            (None, 8000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 48006
# =================================================================
# Total params: 68,606
# Trainable params: 68,606
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath = "best_model.{epoch:02d}-{val_loss:.2f}.h5",
        monitor = "val_loss", save_best_only = True),
    keras.callbacks.EarlyStopping(monitor = "acc", patience = 1)
]

model_m.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# Hyper-parameters
BATCH_SIZE = 400
EPOCHS = 50

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m.fit(x_train, y_train_hot, batch_size = BATCH_SIZE, epochs = EPOCHS,
                      callbacks = callbacks_list, validation_split = 0.2, verbose = 1)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 4s 94ms/step - loss: 1.3098 - accuracy: 0.5529 - val_loss: 0.6991 - val_accuracy: 0.8165
# Epoch 2/50
# 42/42 [==============================] - 3s 82ms/step - loss: 0.6096 - accuracy: 0.7887 - val_loss: 0.6407 - val_accuracy: 0.8218
# Epoch 3/50
# 42/42 [==============================] - 3s 80ms/step - loss: 0.5264 - accuracy: 0.8086 - val_loss: 0.6191 - val_accuracy: 0.8306
# Epoch 4/50
# 42/42 [==============================] - 3s 82ms/step - loss: 0.4962 - accuracy: 0.8177 - val_loss: 0.6426 - val_accuracy: 0.8079
# Epoch 5/50
# 42/42 [==============================] - 4s 84ms/step - loss: 0.4572 - accuracy: 0.8355 - val_loss: 0.6471 - val_accuracy: 0.7882
# Epoch 6/50
# 42/42 [==============================] - 4s 88ms/step - loss: 0.4419 - accuracy: 0.8360 - val_loss: 0.6706 - val_accuracy: 0.7873
# Epoch 7/50
# 42/42 [==============================] - 4s 85ms/step - loss: 0.4212 - accuracy: 0.8498 - val_loss: 0.6848 - val_accuracy: 0.7755
# Epoch 8/50
# 42/42 [==============================] - 3s 83ms/step - loss: 0.4004 - accuracy: 0.8583 - val_loss: 0.6477 - val_accuracy: 0.7916
# Epoch 9/50
# 42/42 [==============================] - 3s 83ms/step - loss: 0.4048 - accuracy: 0.8476 - val_loss: 0.6464 - val_accuracy: 0.8098
# Epoch 10/50
# 42/42 [==============================] - 4s 91ms/step - loss: 0.3710 - accuracy: 0.8663 - val_loss: 0.6925 - val_accuracy: 0.7779
# Epoch 11/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.3610 - accuracy: 0.8693 - val_loss: 0.6928 - val_accuracy: 0.7760
# Epoch 12/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.3681 - accuracy: 0.8617 - val_loss: 0.7069 - val_accuracy: 0.7693
# Epoch 13/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.3428 - accuracy: 0.8762 - val_loss: 0.7949 - val_accuracy: 0.7207
# Epoch 14/50
# 42/42 [==============================] - 4s 95ms/step - loss: 0.3332 - accuracy: 0.8784 - val_loss: 0.6889 - val_accuracy: 0.7714
# Epoch 15/50
# 42/42 [==============================] - 4s 105ms/step - loss: 0.3207 - accuracy: 0.8811 - val_loss: 0.7236 - val_accuracy: 0.7595
# Epoch 16/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.3054 - accuracy: 0.8891 - val_loss: 0.6984 - val_accuracy: 0.7817
# Epoch 17/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.3074 - accuracy: 0.8885 - val_loss: 0.7983 - val_accuracy: 0.7135
# Epoch 18/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.3035 - accuracy: 0.8872 - val_loss: 0.7717 - val_accuracy: 0.7405
# Epoch 19/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.2867 - accuracy: 0.8975 - val_loss: 0.7802 - val_accuracy: 0.7317
# Epoch 20/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.2803 - accuracy: 0.8975 - val_loss: 0.8866 - val_accuracy: 0.6828
# Epoch 21/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.2716 - accuracy: 0.8990 - val_loss: 0.9102 - val_accuracy: 0.6926
# Epoch 22/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.2782 - accuracy: 0.8952 - val_loss: 0.7876 - val_accuracy: 0.7667
# Epoch 23/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.2633 - accuracy: 0.9051 - val_loss: 0.8002 - val_accuracy: 0.7712
# Epoch 24/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.2621 - accuracy: 0.8995 - val_loss: 0.8668 - val_accuracy: 0.7005
# Epoch 25/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.2507 - accuracy: 0.9112 - val_loss: 0.8804 - val_accuracy: 0.7175
# Epoch 26/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.2388 - accuracy: 0.9120 - val_loss: 0.8598 - val_accuracy: 0.7221
# Epoch 27/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.2361 - accuracy: 0.9135 - val_loss: 0.8941 - val_accuracy: 0.7111
# Epoch 28/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.2285 - accuracy: 0.9136 - val_loss: 0.9238 - val_accuracy: 0.7084
# Epoch 29/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.2186 - accuracy: 0.9232 - val_loss: 1.0667 - val_accuracy: 0.6540
# Epoch 30/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.2198 - accuracy: 0.9192 - val_loss: 0.9294 - val_accuracy: 0.7077
# Epoch 31/50
# 42/42 [==============================] - 4s 94ms/step - loss: 0.2116 - accuracy: 0.9214 - val_loss: 0.9994 - val_accuracy: 0.6919
# Epoch 32/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.2084 - accuracy: 0.9238 - val_loss: 0.9161 - val_accuracy: 0.7286
# Epoch 33/50
# 42/42 [==============================] - 4s 93ms/step - loss: 0.2118 - accuracy: 0.9198 - val_loss: 1.0536 - val_accuracy: 0.6770
# Epoch 34/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.1984 - accuracy: 0.9292 - val_loss: 1.0048 - val_accuracy: 0.7029
# Epoch 35/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.1988 - accuracy: 0.9274 - val_loss: 1.0952 - val_accuracy: 0.6756
# Epoch 36/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.1910 - accuracy: 0.9328 - val_loss: 1.0655 - val_accuracy: 0.6778
# Epoch 37/50
# 42/42 [==============================] - 4s 93ms/step - loss: 0.1976 - accuracy: 0.9308 - val_loss: 0.9783 - val_accuracy: 0.7271
# Epoch 38/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.1830 - accuracy: 0.9331 - val_loss: 1.1724 - val_accuracy: 0.6600
# Epoch 39/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.1862 - accuracy: 0.9344 - val_loss: 1.0202 - val_accuracy: 0.7080
# Epoch 40/50
# 42/42 [==============================] - 4s 93ms/step - loss: 0.1691 - accuracy: 0.9410 - val_loss: 0.9838 - val_accuracy: 0.7278
# Epoch 41/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.1797 - accuracy: 0.9313 - val_loss: 1.0839 - val_accuracy: 0.6953
# Epoch 42/50
# 42/42 [==============================] - 4s 94ms/step - loss: 0.1650 - accuracy: 0.9408 - val_loss: 1.1141 - val_accuracy: 0.6945
# Epoch 43/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.1663 - accuracy: 0.9374 - val_loss: 1.2947 - val_accuracy: 0.6428
# Epoch 44/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.1620 - accuracy: 0.9410 - val_loss: 1.0660 - val_accuracy: 0.7151
# Epoch 45/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.1553 - accuracy: 0.9437 - val_loss: 1.1329 - val_accuracy: 0.7137
# Epoch 46/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.1571 - accuracy: 0.9453 - val_loss: 1.1262 - val_accuracy: 0.6984
# Epoch 47/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.1374 - accuracy: 0.9523 - val_loss: 1.2865 - val_accuracy: 0.6624
# Epoch 48/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.1374 - accuracy: 0.9528 - val_loss: 1.2314 - val_accuracy: 0.6749
# Epoch 49/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.1412 - accuracy: 0.9510 - val_loss: 1.1897 - val_accuracy: 0.6912
# Epoch 50/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.1442 - accuracy: 0.9477 - val_loss: 1.1427 - val_accuracy: 0.7027

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history["accuracy"], 'r', label = "Accuracy of training data")
plt.plot(history.history["val_accuracy"], 'b', label = "Accuracy of validation data")
plt.plot(history.history["loss"], 'r--', label = "Loss of training data")
plt.plot(history.history["val_loss"], 'b--', label = "Loss of validation data")
plt.title("Model Accuracy and Loss")
plt.ylabel("Accuracy and Loss")
plt.xlabel("Training Epoch")
plt.ylim(0)
plt.legend()
plt.show()

# Print confusion matrix for training data
y_pred_train = model_m.predict(x_train)
# Take the class with the highest probability from the train predictions
max_y_pred_train = np.argmax(y_pred_train, axis = 1)
print(classification_report(y_train, max_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.62      0.68      1864
#          1.0       0.98      0.97      0.98      6567
#          2.0       0.99      1.00      1.00      1050
#          3.0       1.00      0.99      0.99       833
#          4.0       0.68      0.77      0.72      2342
#          5.0       0.91      0.92      0.91      8212
#
#     accuracy                           0.90     20868
#    macro avg       0.89      0.88      0.88     20868
# weighted avg       0.90      0.90      0.90     20868
